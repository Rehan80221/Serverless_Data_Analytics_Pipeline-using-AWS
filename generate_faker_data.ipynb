# %%
pip install Faker boto3
# Out:
# Collecting Faker
#   Obtaining dependency information for Faker from https://files.pythonhosted.org/packages/d7/a1/8936bc8e79af80ca38288dd93ed44ed1f9d63beb25447a4c59e746e01f8d/faker-37.1.0-py3-none-any.whl.metadata
#   Downloading faker-37.1.0-py3-none-any.whl.metadata (15 kB)
# Collecting boto3
#   Obtaining dependency information for boto3 from https://files.pythonhosted.org/packages/5d/76/2723dede8c69d04e37f0897e9c05b597b6906df3d4c80186e39a0bc1b914/boto3-1.37.28-py3-none-any.whl.metadata
#   Downloading boto3-1.37.28-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: tzdata in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from Faker) (2023.3)
# Collecting botocore<1.38.0,>=1.37.28 (from boto3)
#   Obtaining dependency information for botocore<1.38.0,>=1.37.28 from https://files.pythonhosted.org/packages/ea/c3/29ffcb4c90492bcfcff1b7e5ddb5529846acc0e627569432db9842c47675/botocore-1.37.28-py3-none-any.whl.metadata
#   Downloading botocore-1.37.28-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from boto3) (1.0.1)
# Collecting s3transfer<0.12.0,>=0.11.0 (from boto3)
#   Obtaining dependency information for s3transfer<0.12.0,>=0.11.0 from https://files.pythonhosted.org/packages/86/62/8d3fc3ec6640161a5649b2cddbbf2b9fa39c92541225b33f117c37c5a2eb/s3transfer-0.11.4-py3-none-any.whl.metadata
#   Downloading s3transfer-0.11.4-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from botocore<1.38.0,>=1.37.28->boto3) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from botocore<1.38.0,>=1.37.28->boto3) (2.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.38.0,>=1.37.28->boto3) (1.16.0)
# Downloading faker-37.1.0-py3-none-any.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/1.9 MB 3.6 MB/s eta 0:00:01
#    -------- ------------------------------- 0.4/1.9 MB 6.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.8/1.9 MB 6.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.4/1.9 MB 8.8 MB/s eta 0:00:01
#    ------------------------------------ --- 1.7/1.9 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 7.2 MB/s eta 0:00:00
# Downloading boto3-1.37.28-py3-none-any.whl (139 kB)
#    ---------------------------------------- 0.0/139.6 kB ? eta -:--:--
#    ---------------------------------------- 139.6/139.6 kB 4.2 MB/s eta 0:00:00
# Downloading botocore-1.37.28-py3-none-any.whl (13.5 MB)
#    ---------------------------------------- 0.0/13.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/13.5 MB 9.6 MB/s eta 0:00:02
#    - -------------------------------------- 0.6/13.5 MB 7.9 MB/s eta 0:00:02
#    -- ------------------------------------- 1.0/13.5 MB 7.9 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.4/13.5 MB 7.9 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.6/13.5 MB 7.1 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.9/13.5 MB 6.9 MB/s eta 0:00:02
#    ------- -------------------------------- 2.4/13.5 MB 7.8 MB/s eta 0:00:02
#    -------- ------------------------------- 2.9/13.5 MB 8.0 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.4/13.5 MB 8.3 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.8/13.5 MB 8.4 MB/s eta 0:00:02
#    ------------ --------------------------- 4.3/13.5 MB 8.5 MB/s eta 0:00:02
#    ------------- -------------------------- 4.7/13.5 MB 8.3 MB/s eta 0:00:02
#    --------------- ------------------------ 5.1/13.5 MB 8.5 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.5/13.5 MB 8.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.9/13.5 MB 8.3 MB/s eta 0:00:01
#    ------------------ --------------------- 6.4/13.5 MB 8.5 MB/s eta 0:00:01
#    -------------------- ------------------- 6.9/13.5 MB 8.8 MB/s eta 0:00:01
#    --------------------- ------------------ 7.3/13.5 MB 8.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 7.7/13.5 MB 8.5 MB/s eta 0:00:01
#    ------------------------ --------------- 8.1/13.5 MB 8.5 MB/s eta 0:00:01
#    ------------------------ --------------- 8.4/13.5 MB 8.5 MB/s eta 0:00:01
#    ------------------------- -------------- 8.7/13.5 MB 8.5 MB/s eta 0:00:01
#    --------------------------- ------------ 9.1/13.5 MB 8.3 MB/s eta 0:00:01
#    --------------------------- ------------ 9.4/13.5 MB 8.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 9.6/13.5 MB 8.2 MB/s eta 0:00:01
#    ------------------------------ --------- 10.4/13.5 MB 8.4 MB/s eta 0:00:01
#    ------------------------------- -------- 10.7/13.5 MB 8.5 MB/s eta 0:00:01
#    -------------------------------- ------- 10.8/13.5 MB 8.5 MB/s eta 0:00:01
#    -------------------------------- ------- 11.0/13.5 MB 8.2 MB/s eta 0:00:01
#    --------------------------------- ------ 11.3/13.5 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.7/13.5 MB 8.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 12.1/13.5 MB 8.5 MB/s eta 0:00:01
#    ------------------------------------ --- 12.4/13.5 MB 8.4 MB/s eta 0:00:01
#    -------------------------------------- - 12.9/13.5 MB 8.5 MB/s eta 0:00:01
#    -------------------------------------- - 13.0/13.5 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------  13.4/13.5 MB 8.2 MB/s eta 0:00:01
#    ---------------------------------------  13.5/13.5 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------  13.5/13.5 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------- 13.5/13.5 MB 7.7 MB/s eta 0:00:00
# Downloading s3transfer-0.11.4-py3-none-any.whl (84 kB)
#    ---------------------------------------- 0.0/84.4 kB ? eta -:--:--
#    ---------------------------------------- 84.4/84.4 kB 4.6 MB/s eta 0:00:00
# Installing collected packages: Faker, botocore, s3transfer, boto3
# Successfully installed Faker-37.1.0 boto3-1.37.28 botocore-1.37.28 s3transfer-0.11.4
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from faker import Faker
import random as rd
import json

# Initialize Faker
fake = Faker()

# Function to generate a single record
def get_data(id, name, country, source):
    return {
        "id": id,
        "name": name,
        "country": country,
        "source": source
    }

# Generate sample record
record = get_data(
    str(rd.randint(1, 100)),
    fake.name(),
    fake.country(),
    "other"
)

# Print as JSON
print(json.dumps(record, indent=2))
# Out:
# {
#   "id": "40",
#   "name": "Christina Mcgee",
#   "country": "French Polynesia",
#   "source": "other"
# }

# %%
#Option A: For Kinesis Data Stream
from faker import Faker
import random as rd
import json
import boto3

access_key = "AKIAYDWHTAA7ZDKKFH2U"
secret_key = "w/Vhioh3j+WEKn2L9LC00MjYQz/ZlhRTkc7dNfJ9"
region = "us-east-1"

session = boto3.Session(aws_access_key_id=access_key, aws_secret_access_key=secret_key, region_name=region)

client = session.client('kinesis')
kinesis_stream = "demo-kinesis-stream-1"
sample = Faker()  

def getData(id, name, country, source):
  return {
    "id": id,
    "name": name,
    "country": country,
    "source": source
  }

temp = 0
while temp < 50:
  source_type = 'local_system' if temp <= 25 else 'other'
  record = json.dumps(getData(str(rd.randint(1, 100)), sample.name(), sample.country(), source_type))
  client.put_record(StreamName=kinesis_stream, Data=record, PartitionKey="1")
  print(record)
  temp += 1
# Out:
# {"id": "38", "name": "Janice Lewis", "country": "Paraguay", "source": "local_system"}
# {"id": "64", "name": "Katelyn Holden", "country": "Netherlands Antilles", "source": "local_system"}
# {"id": "53", "name": "Natalie Martinez", "country": "Comoros", "source": "local_system"}
# {"id": "66", "name": "Robert Hernandez", "country": "Taiwan", "source": "local_system"}
# {"id": "77", "name": "Linda Wright", "country": "Wallis and Futuna", "source": "local_system"}
# {"id": "8", "name": "Elizabeth Mcintyre", "country": "Gambia", "source": "local_system"}
# {"id": "16", "name": "Denise Johnson", "country": "Antarctica (the territory South of 60 deg S)", "source": "local_system"}
# {"id": "52", "name": "John Lewis", "country": "Marshall Islands", "source": "local_system"}
# {"id": "82", "name": "Lisa Kim", "country": "Western Sahara", "source": "local_system"}
# {"id": "2", "name": "Logan Coleman", "country": "San Marino", "source": "local_system"}
# {"id": "38", "name": "Matthew Smith", "country": "Sri Lanka", "source": "local_system"}
# {"id": "51", "name": "Dr. Adam Gilbert", "country": "Rwanda", "source": "local_system"}
# {"id": "83", "name": "Susan Williams", "country": "Italy", "source": "local_system"}
# {"id": "73", "name": "Tammy Nguyen", "country": "Italy", "source": "local_system"}
# {"id": "42", "name": "Melissa Brandt", "country": "Rwanda", "source": "local_system"}
# {"id": "23", "name": "Kathleen Wilson", "country": "Palau", "source": "local_system"}
# {"id": "76", "name": "Travis Hanna", "country": "Angola", "source": "local_system"}
# {"id": "49", "name": "Michael Thomas", "country": "Algeria", "source": "local_system"}
# {"id": "72", "name": "Gary Keller", "country": "Saudi Arabia", "source": "local_system"}
# {"id": "68", "name": "Emily Hatfield", "country": "Greece", "source": "local_system"}
# {"id": "81", "name": "Joseph Griffin", "country": "Heard Island and McDonald Islands", "source": "local_system"}
# {"id": "74", "name": "Brandy Gomez", "country": "Dominican Republic", "source": "local_system"}
# {"id": "50", "name": "Brandi Peterson", "country": "Equatorial Guinea", "source": "local_system"}
# {"id": "65", "name": "Veronica Wong", "country": "Argentina", "source": "local_system"}
# {"id": "28", "name": "Patricia Harris", "country": "Greenland", "source": "local_system"}
# {"id": "58", "name": "Andrea Burch", "country": "Timor-Leste", "source": "local_system"}
# {"id": "20", "name": "Margaret Boyd", "country": "Angola", "source": "other"}
# {"id": "6", "name": "Rickey Peters", "country": "Fiji", "source": "other"}
# {"id": "88", "name": "Samantha Reeves", "country": "Madagascar", "source": "other"}
# {"id": "13", "name": "William Scott", "country": "Norway", "source": "other"}
# {"id": "38", "name": "Carmen Lopez", "country": "Dominica", "source": "other"}
# {"id": "57", "name": "Lisa Cook", "country": "Slovenia", "source": "other"}
# {"id": "86", "name": "Keith Sullivan", "country": "Norway", "source": "other"}
# {"id": "18", "name": "Mary Montgomery", "country": "Serbia", "source": "other"}
# {"id": "54", "name": "Julie Curry", "country": "Grenada", "source": "other"}
# {"id": "15", "name": "Andrew Rodriguez", "country": "Djibouti", "source": "other"}
# {"id": "98", "name": "Michael Garcia", "country": "Afghanistan", "source": "other"}
# {"id": "25", "name": "Martin Buck", "country": "Cote d'Ivoire", "source": "other"}
# {"id": "50", "name": "Danielle Poole", "country": "Costa Rica", "source": "other"}
# {"id": "28", "name": "Becky Morse", "country": "Tonga", "source": "other"}
# {"id": "48", "name": "Jordan Howell", "country": "Monaco", "source": "other"}
# {"id": "37", "name": "John Miller", "country": "Morocco", "source": "other"}
# {"id": "89", "name": "Jason Cox", "country": "Croatia", "source": "other"}
# {"id": "89", "name": "Brent Murray", "country": "Latvia", "source": "other"}
# {"id": "33", "name": "Frederick Jackson Jr.", "country": "Turks and Caicos Islands", "source": "other"}
# {"id": "28", "name": "Sarah Berg", "country": "Djibouti", "source": "other"}
# {"id": "64", "name": "Becky Meyer", "country": "Lao People's Democratic Republic", "source": "other"}
# {"id": "75", "name": "Mrs. Brittany Carter", "country": "South Africa", "source": "other"}
# {"id": "93", "name": "Joshua Brown", "country": "Dominican Republic", "source": "other"}
# {"id": "3", "name": "Faith Gilbert", "country": "Denmark", "source": "other"}

# %%
#Option B: For Kinesis Firehose
from faker import Faker
import random as rd
import json
import boto3

access_key = "AKIAYDWHTAA7ZDKKFH2U"
secret_key = "w/Vhioh3j+WEKn2L9LC00MjYQz/ZlhRTkc7dNfJ9"
region = "us-east-1"

session = boto3.Session(aws_access_key_id=access_key, aws_secret_access_key=secret_key, region_name=region)

client = session.client('firehose')
kinesis_stream = "demo-firehose-stream-1"
sample = Faker()  

def getData(id, name, country, source):
  return {
    "id": id,
    "name": name,
    "country": country,
    "source": source
  }

temp = 1
while temp <= 100:
  source_type = 'databricks' if temp <= 50 else 'other'
  record = json.dumps(getData(rd.randint(1, 100), sample.name(), sample.country(), source_type))
  client.put_record(DeliveryStreamName=kinesis_stream, Record={'Data': record})
  print(record)
  temp += 1
# Out:
# {"id": 22, "name": "Robert Hood", "country": "Iraq", "source": "databricks"}
# {"id": 26, "name": "Steven Fernandez", "country": "Samoa", "source": "databricks"}
# {"id": 7, "name": "Amy Kelley", "country": "Egypt", "source": "databricks"}
# {"id": 90, "name": "Heather Herrera", "country": "Montenegro", "source": "databricks"}
# {"id": 49, "name": "Jose Crawford", "country": "Djibouti", "source": "databricks"}
# {"id": 54, "name": "Valerie Tate", "country": "India", "source": "databricks"}
# {"id": 12, "name": "Matthew Fox", "country": "Canada", "source": "databricks"}
# {"id": 92, "name": "Annette Turner", "country": "Eritrea", "source": "databricks"}
# {"id": 52, "name": "Wendy Wright", "country": "Iceland", "source": "databricks"}
# {"id": 23, "name": "Kristi Silva", "country": "Hong Kong", "source": "databricks"}
# {"id": 17, "name": "Michael Holt", "country": "Iraq", "source": "databricks"}
# {"id": 45, "name": "Tiffany Rodriguez", "country": "Bosnia and Herzegovina", "source": "databricks"}
# {"id": 67, "name": "Nancy Rollins", "country": "Martinique", "source": "databricks"}
# {"id": 38, "name": "Michael Mitchell", "country": "Bulgaria", "source": "databricks"}
# {"id": 71, "name": "Summer Mccullough", "country": "India", "source": "databricks"}
# {"id": 57, "name": "Jessica Garcia", "country": "Kenya", "source": "databricks"}
# {"id": 19, "name": "Amy Flores", "country": "Kazakhstan", "source": "databricks"}
# {"id": 99, "name": "Angela Mcpherson", "country": "Svalbard & Jan Mayen Islands", "source": "databricks"}
# {"id": 89, "name": "Michael Villanueva", "country": "Cambodia", "source": "databricks"}
# {"id": 94, "name": "Veronica James", "country": "Bulgaria", "source": "databricks"}
# {"id": 49, "name": "Daniel Williams", "country": "American Samoa", "source": "databricks"}
# {"id": 37, "name": "Sean Newman", "country": "South Georgia and the South Sandwich Islands", "source": "databricks"}
# {"id": 48, "name": "John Ward", "country": "Saint Pierre and Miquelon", "source": "databricks"}
# {"id": 96, "name": "Christopher Lin", "country": "Turks and Caicos Islands", "source": "databricks"}
# {"id": 30, "name": "Jennifer Rojas", "country": "Cyprus", "source": "databricks"}
# {"id": 99, "name": "Vanessa Sweeney", "country": "Uzbekistan", "source": "databricks"}
# {"id": 7, "name": "Alexis Stevenson", "country": "Marshall Islands", "source": "databricks"}
# {"id": 50, "name": "Rhonda Love", "country": "Tokelau", "source": "databricks"}
# {"id": 36, "name": "Timothy Hickman", "country": "Uganda", "source": "databricks"}
# {"id": 10, "name": "Troy Buck", "country": "Bhutan", "source": "databricks"}
# {"id": 88, "name": "Cristian Brown", "country": "Niger", "source": "databricks"}
# {"id": 6, "name": "Lindsey Esparza", "country": "Mali", "source": "databricks"}
# {"id": 36, "name": "Robin Powell", "country": "Bolivia", "source": "databricks"}
# {"id": 77, "name": "Joshua Peterson", "country": "Dominican Republic", "source": "databricks"}
# {"id": 7, "name": "Thomas Hayes", "country": "Gabon", "source": "databricks"}
# {"id": 23, "name": "Anita Shaw", "country": "Lao People's Democratic Republic", "source": "databricks"}
# {"id": 22, "name": "Stephanie King", "country": "Colombia", "source": "databricks"}
# {"id": 84, "name": "Dennis Frost", "country": "Nigeria", "source": "databricks"}
# {"id": 29, "name": "Laura Wiley", "country": "Christmas Island", "source": "databricks"}
# {"id": 87, "name": "Stephanie Steele", "country": "Isle of Man", "source": "databricks"}
# {"id": 25, "name": "Katherine Gordon", "country": "Sudan", "source": "databricks"}
# {"id": 75, "name": "Kara Walsh", "country": "Lithuania", "source": "databricks"}
# {"id": 18, "name": "Melissa Jones", "country": "Estonia", "source": "databricks"}
# {"id": 43, "name": "Barbara Soto", "country": "Angola", "source": "databricks"}
# {"id": 35, "name": "Matthew Rice", "country": "Botswana", "source": "databricks"}
# {"id": 87, "name": "Jose Hunter", "country": "Tajikistan", "source": "databricks"}
# {"id": 69, "name": "David Martin", "country": "Ukraine", "source": "databricks"}
# {"id": 11, "name": "Emma Newman DVM", "country": "Austria", "source": "databricks"}
# {"id": 60, "name": "Leah Dunn", "country": "Jordan", "source": "databricks"}
# {"id": 84, "name": "Kelly Hudson", "country": "Barbados", "source": "databricks"}
# {"id": 39, "name": "Richard Cooley", "country": "Poland", "source": "other"}
# {"id": 43, "name": "Aaron Wilson", "country": "Somalia", "source": "other"}
# {"id": 14, "name": "Craig Parker", "country": "Papua New Guinea", "source": "other"}
# {"id": 75, "name": "Thomas Morgan", "country": "Seychelles", "source": "other"}
# {"id": 33, "name": "Michelle Davenport", "country": "British Virgin Islands", "source": "other"}
# {"id": 82, "name": "Anthony Patterson", "country": "Korea", "source": "other"}
# {"id": 6, "name": "Robert Duran", "country": "Latvia", "source": "other"}
# {"id": 69, "name": "Cynthia Villegas", "country": "Armenia", "source": "other"}
# {"id": 76, "name": "Mitchell Cameron", "country": "Greenland", "source": "other"}
# {"id": 84, "name": "Daniel Chen", "country": "Kuwait", "source": "other"}
# {"id": 40, "name": "Crystal Wilkins", "country": "Cyprus", "source": "other"}
# {"id": 44, "name": "Anna Becker", "country": "Brunei Darussalam", "source": "other"}
# {"id": 91, "name": "Michelle Ramos", "country": "Chad", "source": "other"}
# {"id": 62, "name": "Henry Harris", "country": "Antigua and Barbuda", "source": "other"}
# {"id": 55, "name": "Cindy Fields", "country": "United States of America", "source": "other"}
# {"id": 61, "name": "Robert Griffith", "country": "Panama", "source": "other"}
# {"id": 55, "name": "Geoffrey Ortiz", "country": "Northern Mariana Islands", "source": "other"}
# {"id": 55, "name": "Ryan Herman", "country": "Mozambique", "source": "other"}
# {"id": 70, "name": "Matthew Wong", "country": "Ukraine", "source": "other"}
# {"id": 35, "name": "Sandra Dennis", "country": "Netherlands Antilles", "source": "other"}
# {"id": 54, "name": "Karl Edwards", "country": "Belgium", "source": "other"}
# {"id": 69, "name": "Nathaniel Ortega", "country": "Palau", "source": "other"}
# {"id": 66, "name": "Donna Kane", "country": "Somalia", "source": "other"}
# {"id": 1, "name": "Mary Cook", "country": "Iraq", "source": "other"}
# {"id": 26, "name": "Lawrence Neal", "country": "Ukraine", "source": "other"}
# {"id": 78, "name": "Andres Benjamin", "country": "Congo", "source": "other"}
# {"id": 21, "name": "Caroline Smith", "country": "France", "source": "other"}
# {"id": 55, "name": "Michael Mendoza", "country": "Samoa", "source": "other"}
# {"id": 74, "name": "Emily Macdonald", "country": "Andorra", "source": "other"}
# {"id": 78, "name": "Stephanie Murphy", "country": "Uganda", "source": "other"}
# {"id": 66, "name": "Sergio Bell", "country": "Monaco", "source": "other"}
# {"id": 66, "name": "David Fritz", "country": "Qatar", "source": "other"}
# {"id": 38, "name": "Jason Williamson", "country": "Cambodia", "source": "other"}
# {"id": 66, "name": "Harold Kelly", "country": "Uganda", "source": "other"}
# {"id": 26, "name": "Zachary West", "country": "Guatemala", "source": "other"}
# {"id": 68, "name": "Robert Roberts", "country": "United Kingdom", "source": "other"}
# {"id": 68, "name": "Amy Parks", "country": "Turks and Caicos Islands", "source": "other"}
# {"id": 60, "name": "Michael Moore", "country": "Poland", "source": "other"}
# {"id": 4, "name": "Amy Arnold", "country": "Malaysia", "source": "other"}
# {"id": 61, "name": "Christopher Hernandez", "country": "Afghanistan", "source": "other"}
# {"id": 43, "name": "John Underwood", "country": "Cyprus", "source": "other"}
# {"id": 32, "name": "Charles Lee", "country": "Mayotte", "source": "other"}
# {"id": 34, "name": "Beverly Hartman", "country": "Guatemala", "source": "other"}
# {"id": 13, "name": "Sabrina Stevens", "country": "Barbados", "source": "other"}
# {"id": 63, "name": "Jeffrey Jenkins", "country": "Pakistan", "source": "other"}
# {"id": 68, "name": "Jorge Cisneros", "country": "Saint Vincent and the Grenadines", "source": "other"}
# {"id": 94, "name": "Jennifer Wells", "country": "Turkey", "source": "other"}
# {"id": 24, "name": "Kimberly Nelson", "country": "Guinea-Bissau", "source": "other"}
# {"id": 78, "name": "Tracy Mendoza", "country": "Benin", "source": "other"}
# {"id": 16, "name": "Kathryn Dixon", "country": "Lesotho", "source": "other"}
